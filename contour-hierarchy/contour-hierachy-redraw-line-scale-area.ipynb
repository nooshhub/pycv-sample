# %%
import numpy as np
import cv2 as cv

src = cv.imread('data_hierarchy3.png')
maxSizeOfOriginalSrcImg = max(src.shape[0], src.shape[1])
src = cv.resize(src, (0,0), fx=1000/maxSizeOfOriginalSrcImg, fy=1000/maxSizeOfOriginalSrcImg) 
reDrewnLine = src.copy()

# re-draw  all edges
gray = cv.cvtColor(reDrewnLine, cv.COLOR_BGR2GRAY)
edges = cv.Canny(gray,0,255)
contours1, hierarchy1 = cv.findContours(edges, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
cv.drawContours(reDrewnLine, contours1, -1, (0,0,0), 3)

# get contours by re-draw edges
gray = cv.cvtColor(reDrewnLine, cv.COLOR_BGR2GRAY)
edges = cv.Canny(gray,0,255)
contours1, hierarchy1 = cv.findContours(edges, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# hierarchy [Next, Previous, First_Child, Parent]
print(len(contours1))
print(contours1[0])
print(contours1[0] + 1)

copy = src.copy()
cv.drawContours(copy, contours1, -1, (0,0,0), 1)
currentRootIndex = -1
rootRegions = {}
for i,cnt in enumerate(contours1):
    x,y,w,h = cv.boundingRect(cnt)
    print(i, hierarchy1[0][i])
    if hierarchy1[0][i][3] == -1:
        # root region
        currentRootIndex = i + 1
        if currentRootIndex == len(contours1):
            break
        rootRegion = {'index': i, 'contour': cv.contourArea(contours1[currentRootIndex]), 'childRegion': []}
        rootRegions[currentRootIndex] = rootRegion
    elif hierarchy1[0][i][3] == currentRootIndex:
        rootRegions[currentRootIndex]['childRegion'].append({'index': i, 'contour': cv.contourArea(cnt)})
        
print(rootRegions)        
data2 = json.dumps(rootRegions, sort_keys=True, indent=4, separators=(',', ': '))
print(data2)
    
#     cv.putText(copy, str(i), (x+5,y+10), cv.FONT_HERSHEY_PLAIN, 1,(0,0,0), 1, cv.LINE_AA)

# for i,cnt in enumerate(contours2):    
# #     print(cnt)
#     mask = np.zeros(copy.shape, np.uint8)
#     mask = cv.fillConvexPoly(mask, cnt, (255, 255, 255))
#     grayMask = cv.cvtColor(mask, cv.COLOR_BGR2GRAY)
#     masked = cv.bitwise_and(gray, grayMask)
#     cv.imshow('mask' + str(i), masked)
    
# #     edges = cv.Canny(masked,0,255)
#     contours3, hierarchy3 = cv.findContours(masked, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
# #     maskedCopy = masked.copy()
# #     cv.drawContours(maskedCopy, contours3, -1, (255, 255, 255), 2)
#     print(i, len(contours3), hierarchy3)
    
    
    
cv.imshow('copy', copy)
cv.imshow('gray', gray)
cv.imshow('edges', edges)
# cv.imshow('opening', opening)

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 251
# [[[731 673]]
#
#  [[730 674]]
#
#  [[729 674]]
#
#  [[728 675]]
#
#  [[728 676]]
#
#  [[727 677]]
#
#  [[727 683]]
#
#  [[726 684]]
#
#  [[714 684]]
#
#  [[713 683]]
#
#  [[713 676]]
#
#  [[712 675]]
#
#  [[708 675]]
#
#  [[707 676]]
#
#  [[707 677]]
#
#  [[706 678]]
#
#  [[706 685]]
#
#  [[707 686]]
#
#  [[707 691]]
#
#  [[708 692]]
#
#  [[708 693]]
#
#  [[709 694]]
#
#  [[709 695]]
#
#  [[710 696]]
#
#  [[727 696]]
#
#  [[728 697]]
#
#  [[728 698]]
#
#  [[729 699]]
#
#  [[729 700]]
#
#  [[731 702]]
#
#  [[774 702]]
#
#  [[776 700]]
#
#  [[776 698]]
#
#  [[778 696]]
#
#  [[832 696]]
#
#  [[834 698]]
#
#  [[834 699]]
#
#  [[835 700]]
#
#  [[835 701]]
#
#  [[836 702]]
#
#  [[918 702]]
#
#  [[919 703]]
#
#  [[923 703]]
#
#  [[924 702]]
#
#  [[924 698]]
#
#  [[923 697]]
#
#  [[924 696]]
#
#  [[924 694]]
#
#  [[922 692]]
#
#  [[922 680]]
#
#  [[924 678]]
#
#  [[924 676]]
#
#  [[923 675]]
#
#  [[920 675]]
#
#  [[919 676]]
#
#  [[919 677]]
#
#  [[918 678]]
#
#  [[918 679]]
#
#  [[917 680]]
#
#  [[917 690]]
#
#  [[916 691]]
#
#  [[840 691]]
#
#  [[839 690]]
#
#  [[839 688]]
#
#  [[840 687]]
#
#  [[840 676]]
#
#  [[839 675]]
#
#  [[838 675]]
#
#  [[837 674]]
#
#  [[835 674]]
#
#  [[834 675]]
#
#  [[834 676]]
#
#  [[833 677]]
#
#  [[833 683]]
#
#  [[832 684]]
#
#  [[775 684]]
#
#  [[774 683]]
#
#  [[774 680]]
#
#  [[776 678]]
#
#  [[776 676]]
#
#  [[775 675]]
#
#  [[772 675]]
#
#  [[770 677]]
#
#  [[770 678]]
#
#  [[769 679]]
#
#  [[769 685]]
#
#  [[770 686]]
#
#  [[770 690]]
#
#  [[769 691]]
#
#  [[734 691]]
#
#  [[733 690]]
#
#  [[733 689]]
#
#  [[734 688]]
#
#  [[734 675]]
#
#  [[733 674]]
#
#  [[732 674]]]
# [[[732 674]]
#
#  [[731 675]]
#
#  [[730 675]]
#
#  [[729 676]]
#
#  [[729 677]]
#
#  [[728 678]]
#
#  [[728 684]]
#
#  [[727 685]]
#
#  [[715 685]]
#
#  [[714 684]]
#
#  [[714 677]]
#
#  [[713 676]]
#
#  [[709 676]]
#
#  [[708 677]]
#
#  [[708 678]]
#
#  [[707 679]]
#
#  [[707 686]]
#
#  [[708 687]]
#
#  [[708 692]]
#
#  [[709 693]]
#
#  [[709 694]]
#
#  [[710 695]]
#
#  [[710 696]]
#
#  [[711 697]]
#
#  [[728 697]]
#
#  [[729 698]]
#
#  [[729 699]]
#
#  [[730 700]]
#
#  [[730 701]]
#
#  [[732 703]]
#
#  [[775 703]]
#
#  [[777 701]]
#
#  [[777 699]]
#
#  [[779 697]]
#
#  [[833 697]]
#
#  [[835 699]]
#
#  [[835 700]]
#
#  [[836 701]]
#
#  [[836 702]]
#
#  [[837 703]]
#
#  [[919 703]]
#
#  [[920 704]]
#
#  [[924 704]]
#
#  [[925 703]]
#
#  [[925 699]]
#
#  [[924 698]]
#
#  [[925 697]]
#
#  [[925 695]]
#
#  [[923 693]]
#
#  [[923 681]]
#
#  [[925 679]]
#
#  [[925 677]]
#
#  [[924 676]]
#
#  [[921 676]]
#
#  [[920 677]]
#
#  [[920 678]]
#
#  [[919 679]]
#
#  [[919 680]]
#
#  [[918 681]]
#
#  [[918 691]]
#
#  [[917 692]]
#
#  [[841 692]]
#
#  [[840 691]]
#
#  [[840 689]]
#
#  [[841 688]]
#
#  [[841 677]]
#
#  [[840 676]]
#
#  [[839 676]]
#
#  [[838 675]]
#
#  [[836 675]]
#
#  [[835 676]]
#
#  [[835 677]]
#
#  [[834 678]]
#
#  [[834 684]]
#
#  [[833 685]]
#
#  [[776 685]]
#
#  [[775 684]]
#
#  [[775 681]]
#
#  [[777 679]]
#
#  [[777 677]]
#
#  [[776 676]]
#
#  [[773 676]]
#
#  [[771 678]]
#
#  [[771 679]]
#
#  [[770 680]]
#
#  [[770 686]]
#
#  [[771 687]]
#
#  [[771 691]]
#
#  [[770 692]]
#
#  [[735 692]]
#
#  [[734 691]]
#
#  [[734 690]]
#
#  [[735 689]]
#
#  [[735 676]]
#
#  [[734 675]]
#
#  [[733 675]]]
# 0 [ 2 -1  1 -1]
# 1 [-1 -1 -1  0]
# 2 [ 4  0  3 -1]
# 3 [-1 -1 -1  2]
# 4 [ 6  2  5 -1]
# 5 [-1 -1 -1  4]
# 6 [10  4  7 -1]
# 7 [-1 -1  8  6]
# 8 [ 9 -1 -1  7]
# 9 [-1  8 -1  7]
# 10 [15  6 11 -1]
# 11 [-1 -1 12 10]
# 12 [13 -1 -1 11]
# 13 [14 12 -1 11]
# 14 [-1 13 -1 11]
# 15 [19 10 16 -1]
# 16 [-1 -1 17 15]
# 17 [-1 -1 18 16]
# 18 [-1 -1 -1 17]
# 19 [20 15 -1 -1]
# 20 [27 19 21 -1]
# 21 [-1 -1 22 20]
# 22 [24 -1 23 21]
# 23 [-1 -1 -1 22]
# 24 [25 22 -1 21]
# 25 [-1 24 26 21]
# 26 [-1 -1 -1 25]
# 27 [28 20 -1 -1]
# 28 [29 27 -1 -1]
# 29 [30 28 -1 -1]
# 30 [32 29 31 -1]
# 31 [-1 -1 -1 30]
# 32 [33 30 -1 -1]
# 33 [35 32 34 -1]
# 34 [-1 -1 -1 33]
# 35 [36 33 -1 -1]
# 36 [37 35 -1 -1]
# 37 [38 36 -1 -1]
# 38 [39 37 -1 -1]
# 39 [40 38 -1 -1]
# 40 [41 39 -1 -1]
# 41 [42 40 -1 -1]
# 42 [43 41 -1 -1]
# 43 [44 42 -1 -1]
# 44 [45 43 -1 -1]
# 45 [46 44 -1 -1]
# 46 [47 45 -1 -1]
# 47 [48 46 -1 -1]
# 48 [49 47 -1 -1]
# 49 [50 48 -1 -1]
# 50 [52 49 51 -1]
# 51 [-1 -1 -1 50]
# 52 [53 50 -1 -1]
# 53 [54 52 -1 -1]
# 54 [55 53 -1 -1]
# 55 [56 54 -1 -1]
# 56 [57 55 -1 -1]
# 57 [58 56 -1 -1]
# 58 [59 57 -1 -1]
# 59 [60 58 -1 -1]
# 60 [61 59 -1 -1]
# 61 [62 60 -1 -1]
# 62 [64 61 63 -1]
# 63 [-1 -1 -1 62]
# 64 [66 62 65 -1]
# 65 [-1 -1 -1 64]
# 66 [68 64 67 -1]
# 67 [-1 -1 -1 66]
# 68 [69 66 -1 -1]
# 69 [71 68 70 -1]
# 70 [-1 -1 -1 69]
# 71 [73 69 72 -1]
# 72 [-1 -1 -1 71]
# 73 [75 71 74 -1]
# 74 [-1 -1 -1 73]
# 75 [77 73 76 -1]
# 76 [-1 -1 -1 75]
# 77 [78 75 -1 -1]
# 78 [80 77 79 -1]
# 79 [-1 -1 -1 78]
# 80 [83 78 81 -1]
# 81 [-1 -1 82 80]
# 82 [-1 -1 -1 81]
# 83 [87 80 84 -1]
# 84 [-1 -1 85 83]
# 85 [-1 -1 86 84]
# 86 [-1 -1 -1 85]
# 87 [89 83 88 -1]
# 88 [-1 -1 -1 87]
# 89 [90 87 -1 -1]
# 90 [92 89 91 -1]
# 91 [-1 -1 -1 90]
# 92 [94 90 93 -1]
# 93 [-1 -1 -1 92]
# 94 [96 92 95 -1]
# 95 [-1 -1 -1 94]
# 96 [97 94 -1 -1]
# 97 [99 96 98 -1]
# 98 [-1 -1 -1 97]
# 99 [103  97 100  -1]
# 100 [ -1  -1 101  99]
# 101 [ -1  -1 102 100]
# 102 [ -1  -1  -1 101]
# 103 [104  99  -1  -1]
# 104 [105 103  -1  -1]
# 105 [106 104  -1  -1]
# 106 [107 105  -1  -1]
# 107 [108 106  -1  -1]
# 108 [112 107 109  -1]
# 109 [ -1  -1 110 108]
# 110 [ -1  -1 111 109]
# 111 [ -1  -1  -1 110]
# 112 [115 108 113  -1]
# 113 [114  -1  -1 112]
# 114 [ -1 113  -1 112]
# 115 [117 112 116  -1]
# 116 [ -1  -1  -1 115]
# 117 [119 115 118  -1]
# 118 [ -1  -1  -1 117]
# 119 [123 117 120  -1]
# 120 [ -1  -1 121 119]
# 121 [ -1  -1 122 120]
# 122 [ -1  -1  -1 121]
# 123 [124 119  -1  -1]
# 124 [125 123  -1  -1]
# 125 [126 124  -1  -1]
# 126 [127 125  -1  -1]
# 127 [131 126 128  -1]
# 128 [ -1  -1 129 127]
# 129 [ -1  -1 130 128]
# 130 [ -1  -1  -1 129]
# 131 [132 127  -1  -1]
# 132 [133 131  -1  -1]
# 133 [134 132  -1  -1]
# 134 [135 133  -1  -1]
# 135 [140 134 136  -1]
# 136 [137  -1  -1 135]
# 137 [ -1 136 138 135]
# 138 [ -1  -1 139 137]
# 139 [ -1  -1  -1 138]
# 140 [142 135 141  -1]
# 141 [ -1  -1  -1 140]
# 142 [147 140 143  -1]
# 143 [144  -1  -1 142]
# 144 [ -1 143 145 142]
# 145 [ -1  -1 146 144]
# 146 [ -1  -1  -1 145]
# 147 [151 142 148  -1]
# 148 [ -1  -1 149 147]
# 149 [ -1  -1 150 148]
# 150 [ -1  -1  -1 149]
# 151 [153 147 152  -1]
# 152 [ -1  -1  -1 151]
# 153 [157 151 154  -1]
# 154 [ -1  -1 155 153]
# 155 [ -1  -1 156 154]
# 156 [ -1  -1  -1 155]
# 157 [159 153 158  -1]
# 158 [ -1  -1  -1 157]
# 159 [164 157 160  -1]
# 160 [ -1  -1 161 159]
# 161 [162  -1  -1 160]
# 162 [ -1 161 163 160]
# 163 [ -1  -1  -1 162]
# 164 [171 159 165  -1]
# 165 [ -1  -1 166 164]
# 166 [167  -1  -1 165]
# 167 [168 166  -1 165]
# 168 [169 167  -1 165]
# 169 [ -1 168 170 165]
# 170 [ -1  -1  -1 169]
# 171 [173 164 172  -1]
# 172 [ -1  -1  -1 171]
# 173 [177 171 174  -1]
# 174 [ -1  -1 175 173]
# 175 [ -1  -1 176 174]
# 176 [ -1  -1  -1 175]
# 177 [179 173 178  -1]
# 178 [ -1  -1  -1 177]
# 179 [183 177 180  -1]
# 180 [ -1  -1 181 179]
# 181 [ -1  -1 182 180]
# 182 [ -1  -1  -1 181]
# 183 [184 179  -1  -1]
# 184 [186 183 185  -1]
# 185 [ -1  -1  -1 184]
# 186 [187 184  -1  -1]
# 187 [191 186 188  -1]
# 188 [ -1  -1 189 187]
# 189 [ -1  -1 190 188]
# 190 [ -1  -1  -1 189]
# 191 [199 187 192  -1]
# 192 [ -1  -1 193 191]
# 193 [195  -1 194 192]
# 194 [ -1  -1  -1 193]
# 195 [197 193 196 192]
# 196 [ -1  -1  -1 195]
# 197 [ -1 195 198 192]
# 198 [ -1  -1  -1 197]
# 199 [202 191 200  -1]
# 200 [ -1  -1 201 199]
# 201 [ -1  -1  -1 200]
# 202 [204 199 203  -1]
# 203 [ -1  -1  -1 202]
# 204 [206 202 205  -1]
# 205 [ -1  -1  -1 204]
# 206 [208 204 207  -1]
# 207 [ -1  -1  -1 206]
# 208 [210 206 209  -1]
# 209 [ -1  -1  -1 208]
# 210 [216 208 211  -1]
# 211 [ -1  -1 212 210]
# 212 [213  -1  -1 211]
# 213 [215 212 214 211]
# 214 [ -1  -1  -1 213]
# 215 [ -1 213  -1 211]
# 216 [217 210  -1  -1]
# 217 [218 216  -1  -1]
# 218 [222 217 219  -1]
# 219 [ -1  -1 220 218]
# 220 [ -1  -1 221 219]
# 221 [ -1  -1  -1 220]
# 222 [223 218  -1  -1]
# 223 [227 222 224  -1]
# 224 [ -1  -1 225 223]
# 225 [ -1  -1 226 224]
# 226 [ -1  -1  -1 225]
# 227 [229 223 228  -1]
# 228 [ -1  -1  -1 227]
# 229 [233 227 230  -1]
# 230 [ -1  -1 231 229]
# 231 [ -1  -1 232 230]
# 232 [ -1  -1  -1 231]
# 233 [237 229 234  -1]
# 234 [ -1  -1 235 233]
# 235 [ -1  -1 236 234]
# 236 [ -1  -1  -1 235]
# 237 [243 233 238  -1]
# 238 [ -1  -1 239 237]
# 239 [241  -1 240 238]
# 240 [ -1  -1  -1 239]
# 241 [ -1 239 242 238]
# 242 [ -1  -1  -1 241]
# 243 [245 237 244  -1]
# 244 [ -1  -1  -1 243]
# 245 [246 243  -1  -1]
# 246 [250 245 247  -1]
# 247 [ -1  -1 248 246]
# 248 [ -1  -1 249 247]
# 249 [ -1  -1  -1 248]
# 250 [ -1 246  -1  -1]
# {1: {'index': 0, 'contour': 2867.0, 'childRegion': []}, 3: {'index': 2, 'contour': 10.0, 'childRegion': []}, 5: {'index': 4, 'contour': 88.0, 'childRegion': []}, 7: {'index': 6, 'contour': 310.5, 'childRegion': [{'index': 8, 'contour': 0.0}, {'index': 9, 'contour': 0.0}]}, 11: {'index': 10, 'contour': 366.0, 'childRegion': [{'index': 12, 'contour': 0.0}, {'index': 13, 'contour': 0.0}, {'index': 14, 'contour': 2.0}]}, 16: {'index': 15, 'contour': 259.0, 'childRegion': [{'index': 17, 'contour': 6.0}]}, 20: {'index': 19, 'contour': 6075.0, 'childRegion': []}, 21: {'index': 20, 'contour': 6066.0, 'childRegion': [{'index': 22, 'contour': 473.5}, {'index': 24, 'contour': 0.5}, {'index': 25, 'contour': 2320.5}]}, 28: {'index': 27, 'contour': 0.0, 'childRegion': []}, 29: {'index': 28, 'contour': 0.0, 'childRegion': []}, 30: {'index': 29, 'contour': 5.0, 'childRegion': []}, 31: {'index': 30, 'contour': 4.0, 'childRegion': []}, 33: {'index': 32, 'contour': 48.5, 'childRegion': []}, 34: {'index': 33, 'contour': 8.0, 'childRegion': []}, 36: {'index': 35, 'contour': 0.5, 'childRegion': []}, 37: {'index': 36, 'contour': 0.0, 'childRegion': []}, 38: {'index': 37, 'contour': 0.0, 'childRegion': []}, 39: {'index': 38, 'contour': 0.0, 'childRegion': []}, 40: {'index': 39, 'contour': 10.0, 'childRegion': []}, 41: {'index': 40, 'contour': 0.0, 'childRegion': []}, 42: {'index': 41, 'contour': 0.0, 'childRegion': []}, 43: {'index': 42, 'contour': 0.5, 'childRegion': []}, 44: {'index': 43, 'contour': 0.0, 'childRegion': []}, 45: {'index': 44, 'contour': 0.5, 'childRegion': []}, 46: {'index': 45, 'contour': 0.0, 'childRegion': []}, 47: {'index': 46, 'contour': 0.0, 'childRegion': []}, 48: {'index': 47, 'contour': 0.5, 'childRegion': []}, 49: {'index': 48, 'contour': 0.0, 'childRegion': []}, 50: {'index': 49, 'contour': 18.5, 'childRegion': []}, 51: {'index': 50, 'contour': 14.5, 'childRegion': []}, 53: {'index': 52, 'contour': 0.5, 'childRegion': []}, 54: {'index': 53, 'contour': 0.5, 'childRegion': []}, 55: {'index': 54, 'contour': 0.5, 'childRegion': []}, 56: {'index': 55, 'contour': 0.5, 'childRegion': []}, 57: {'index': 56, 'contour': 0.5, 'childRegion': []}, 58: {'index': 57, 'contour': 0.5, 'childRegion': []}, 59: {'index': 58, 'contour': 0.5, 'childRegion': []}, 60: {'index': 59, 'contour': 0.5, 'childRegion': []}, 61: {'index': 60, 'contour': 0.5, 'childRegion': []}, 62: {'index': 61, 'contour': 3.5, 'childRegion': []}, 63: {'index': 62, 'contour': 2.0, 'childRegion': []}, 65: {'index': 64, 'contour': 2.0, 'childRegion': []}, 67: {'index': 66, 'contour': 2.0, 'childRegion': []}, 69: {'index': 68, 'contour': 4.0, 'childRegion': []}, 70: {'index': 69, 'contour': 2.0, 'childRegion': []}, 72: {'index': 71, 'contour': 2.0, 'childRegion': []}, 74: {'index': 73, 'contour': 10674.5, 'childRegion': []}, 76: {'index': 75, 'contour': 2.0, 'childRegion': []}, 78: {'index': 77, 'contour': 19.0, 'childRegion': []}, 79: {'index': 78, 'contour': 18.0, 'childRegion': []}, 81: {'index': 80, 'contour': 361.5, 'childRegion': [{'index': 82, 'contour': 0.0}]}, 84: {'index': 83, 'contour': 1712.0, 'childRegion': [{'index': 85, 'contour': 947.0}]}, 88: {'index': 87, 'contour': 2.0, 'childRegion': []}, 90: {'index': 89, 'contour': 4.0, 'childRegion': []}, 91: {'index': 90, 'contour': 2.0, 'childRegion': []}, 93: {'index': 92, 'contour': 387.0, 'childRegion': []}, 95: {'index': 94, 'contour': 4.0, 'childRegion': []}, 97: {'index': 96, 'contour': 5.0, 'childRegion': []}, 98: {'index': 97, 'contour': 4.0, 'childRegion': []}, 100: {'index': 99, 'contour': 1697.5, 'childRegion': [{'index': 101, 'contour': 936.5}]}, 104: {'index': 103, 'contour': 0.0, 'childRegion': []}, 105: {'index': 104, 'contour': 1.0, 'childRegion': []}, 106: {'index': 105, 'contour': 0.0, 'childRegion': []}, 107: {'index': 106, 'contour': 0.0, 'childRegion': []}, 108: {'index': 107, 'contour': 1076.0, 'childRegion': []}, 109: {'index': 108, 'contour': 1068.0, 'childRegion': [{'index': 110, 'contour': ...
# {
#     "1": {
#         "childRegion": [],
#         "contour": 2867.0,
#         "index": 0
#     },
#     "3": {
#         "childRegion": [],
#         "contour": 10.0,
#         "index": 2
#     },
#     "5": {
#         "childRegion": [],
#         "contour": 88.0,
#         "index": 4
#     },
#     "7": {
#         "childRegion": [
#             {
#                 "contour": 0.0,
#                 "index": 8
#             },
#             {
#                 "contour": 0.0,
#                 "index": 9
#             }
#         ],
#         "contour": 310.5,
#         "index": 6
#     },
#     "11": {
#         "childRegion": [
#             {
#                 "contour": 0.0,
#                 "index": 12
#             },
#             {
#                 "contour": 0.0,
#                 "index": 13
#             },
#             {
#                 "contour": 2.0,
#                 "index": 14
#             }
#         ],
#         "contour": 366.0,
#         "index": 10
#     },
#     "16": {
#         "childRegion": [
#             {
#                 "contour": 6.0,
#                 "index": 17
#             }
#         ],
#         "contour": 259.0,
#         "index": 15
#     },
#     "20": {
#         "childRegion": [],
#         "contour": 6075.0,
#         "index": 19
#     },
#     "21": {
#         "childRegion": [
#             {
#                 "contour": 473.5,
#                 "index": 22
#             },
#             {
#                 "contour": 0.5,
#                 "index": 24
#             },
#             {
#                 "contour": 2320.5,
#                 "index": 25
#             }
#         ],
#         "contour": 6066.0,
#         "index": 20
#     },
#     "28": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 27
#     },
#     "29": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 28
#     },
#     "30": {
#         "childRegion": [],
#         "contour": 5.0,
#         "index": 29
#     },
#     "31": {
#         "childRegion": [],
#         "contour": 4.0,
#         "index": 30
#     },
#     "33": {
#         "childRegion": [],
#         "contour": 48.5,
#         "index": 32
#     },
#     "34": {
#         "childRegion": [],
#         "contour": 8.0,
#         "index": 33
#     },
#     "36": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 35
#     },
#     "37": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 36
#     },
#     "38": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 37
#     },
#     "39": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 38
#     },
#     "40": {
#         "childRegion": [],
#         "contour": 10.0,
#         "index": 39
#     },
#     "41": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 40
#     },
#     "42": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 41
#     },
#     "43": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 42
#     },
#     "44": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 43
#     },
#     "45": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 44
#     },
#     "46": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 45
#     },
#     "47": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 46
#     },
#     "48": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 47
#     },
#     "49": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 48
#     },
#     "50": {
#         "childRegion": [],
#         "contour": 18.5,
#         "index": 49
#     },
#     "51": {
#         "childRegion": [],
#         "contour": 14.5,
#         "index": 50
#     },
#     "53": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 52
#     },
#     "54": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 53
#     },
#     "55": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 54
#     },
#     "56": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 55
#     },
#     "57": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 56
#     },
#     "58": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 57
#     },
#     "59": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 58
#     },
#     "60": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 59
#     },
#     "61": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 60
#     },
#     "62": {
#         "childRegion": [],
#         "contour": 3.5,
#         "index": 61
#     },
#     "63": {
#         "childRegion": [],
#         "contour": 2.0,
#         "index": 62
#     },
#     "65": {
#         "childRegion": [],
#         "contour": 2.0,
#         "index": 64
#     },
#     "67": {
#         "childRegion": [],
#         "contour": 2.0,
#         "index": 66
#     },
#     "69": {
#         "childRegion": [],
#         "contour": 4.0,
#         "index": 68
#     },
#     "70": {
#         "childRegion": [],
#         "contour": 2.0,
#         "index": 69
#     },
#     "72": {
#         "childRegion": [],
#         "contour": 2.0,
#         "index": 71
#     },
#     "74": {
#         "childRegion": [],
#         "contour": 10674.5,
#         "index": 73
#     },
#     "76": {
#         "childRegion": [],
#         "contour": 2.0,
#         "index": 75
#     },
#     "78": {
#         "childRegion": [],
#         "contour": 19.0,
#         "index": 77
#     },
#     "79": {
#         "childRegion": [],
#         "contour": 18.0,
#         "index": 78
#     },
#     "81": {
#         "childRegion": [
#             {
#                 "contour": 0.0,
#                 "index": 82
#             }
#         ],
#         "contour": 361.5,
#         "index": 80
#     },
#     "84": {
#         "childRegion": [
#             {
#                 "contour": 947.0,
#                 "index": 85
#             }
#         ],
#         "contour": 1712.0,
#         "index": 83
#     },
#     "88": {
#         "childRegion": [],
#         "contour": 2.0,
#         "index": 87
#     },
#     "90": {
#         "childRegion": [],
#         "contour": 4.0,
#         "index": 89
#     },
#     "91": {
#         "childRegion": [],
#         "contour": 2.0,
#         "index": 90
#     },
#     "93": {
#         "childRegion": [],
#         "contour": 387.0,
#         "index": 92
#     },
#     "95": {
#         "childRegion": [],
#         "contour": 4.0,
#         "index": 94
#     },
#     "97": {
#         "childRegion": [],
#         "contour": 5.0,
#         "index": 96
#     },
#     "98": {
#         "childRegion": [],
#         "contour": 4.0,
#         "index": 97
#     },
#     "100": {
#         "childRegion": [
#             {
#                 "contour": 936.5,
#                 "index": 101
#             }
#         ],
#         "contour": 1697.5,
#         "index": 99
#     },
#     "104": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 103
#     },
#     "105": {
#         "childRegion": [],
#         "contour": 1.0,
#         "index": 104
#     },
#     "106": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 105
#     },
#     "107": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 106
#     },
#     "108": {
#         "childRegion": [],
#         "contour": 1076.0,
#         "index": 107
#     },
#     "109": {
#         "childRegion": [
#             {
#                 "contour": 541.0,
#                 "index": 110
#             }
#         ],
#         "contour": 1068.0,
#         "index": 108
#     },
#     "113": {
#         "childRegion": [],
#         "contour": 5.5,
#         "index": 112
#     },
#     "116": {
#         "childRegion": [],
#         "contour": 4.0,
#         "index": 115
#     },
#     "118": {
#         "childRegion": [],
#         "contour": 1291.0,
#         "index": 117
#     },
#     "120": {
#         "childRegion": [
#             {
#                 "contour": 908.5,
#                 "index": 121
#             }
#         ],
#         "contour": 1677.5,
#         "index": 119
#     },
#     "124": {
#         "childRegion": [],
#         "contour": 11.0,
#         "index": 123
#     },
#     "125": {
#         "childRegion": [],
#         "contour": 9.0,
#         "index": 124
#     },
#     "126": {
#         "childRegion": [],
#         "contour": 77.0,
#         "index": 125
#     },
#     "127": {
#         "childRegion": [],
#         "contour": 655.5,
#         "index": 126
#     },
#     "128": {
#         "childRegion": [
#             {
#                 "contour": 251.0,
#                 "index": 129
#             }
#         ],
#         "contour": 649.5,
#         "index": 127
#     },
#     "132": {
#         "childRegion": [],
#         "contour": 0.0,
#         "index": 131
#     },
#     "133": {
#         "childRegion": [],
#         "contour": 0.5,
#         "index": 132
#     },
#     "134": {
#         "childRegion": [],
#         "contour": 76.0,
#         "index": 133
#     },
#     "135": {
#         "childRegion": [],
#         "contour": 1879.0,
#         "index": 134
#     },
#     "136": {
#         "childRegion": [],
#         "contour": 6.0,
#         "index": 135
#     },
#     "141": {
#         "childRegion": [],
#         "contour": 172.5,
#         "index": 140
#     },
#     "143": {
#         "childRegion": [],
#         "contour": 7.0,
#         "index": 142
#     },
#     "148": {
#         "childRegion": [
#             {
#                 "contour": 997.0,
#                 "index": 149
#             }
#         ],
#         "contour": 1763.0,
#         "index": 147
#     },
#     "152": {
#         "childRegion": [],
#         "contour": 183.5,
#         "index": 151
#     },
#     "154": {
#         "childRegion": [
#             {
#                 "contour": 928.0,
#                 "index": 155
#             }
#         ],
#         "contour": 1692.0,
#         "index": 153
#     },
#     "158": {
#         "childRegion": [],
#         "contour": 610.0,
#         "index": 157
#     },
#     "160": {
#         "childRegion": [
#             {
#                 "contour": 0.0,
#                 "index": 161
#             },
#             {
#                 "contour": 886.5,
#                 "index": 162
#             }
#         ],
#         "contour": 2432.5,
#         "index": 159
#     },
#     "165": {
#         "childRegion": [
#             {
#                 "contour": 0.0,
#                 "index": 166
#             },
#             {
#                 "contour": 0.0,
#                 "index": 167
#             },
#             {
#                 "contour": 0.0,
#                 "index": 168
#             },
#             {
#                 "contour": 4.0,
#                 "index": 169
#             }
#         ],
#         "contour": 274.5,
#         "index": 164
#     },
#     "172": {
#         "childRegion": [],
#         "contour": 269.0,
#         "index": 171
#     },
#     "174": {
#         "childRegion": [
#             {
#                 "contour": 10001.0,
#                 "index": 175
#             }
#         ],
#         "contour": 12012.5,
#         "index": 173
#     },
#     "178": {
#         "childRegion": [],
#         "contour": 285.5,
#         "index": 177
#     },
#     "180": {
#         "childRegion": [
#             {
#                 "contour": 10112.5,
#                 "index": 181
#             }
#         ],
#         "contour": 12160.0,
#         "index": 179
#     },
#     "184": {
#         "childRegion": [],
#         "contour": 520.5,
#         "index": 183
#     },
#     "185": {
#         "childRegion": [],
#         "contour": 520.0,
#         "index": 184
#     },
#     "187": {
#         "childRegion": [],
#         "contour": 1060.0,
#         "index": 186
#     },
#     "188": {
#         "childRegion": [
#             {
#                 "contour": 478.0,
#                 "index": 189
#             }
#         ],
#         "contour": 1052.0,
#         "index": 187
#     },
#     "192": {
#         "childRegion": [
#             {
#                 "contour": 241.0,
#                 "index": 193
#             },
#             {
#                 "contour": 141.0,
#                 "index": 195
#             },
#             {
#                 "contour": 552.0,
#                 "index": 197
#             }
#         ],
#         "contour": 2200.0,
#         "index": 191
#     },
#     "200": {
#         "childRegion": [
#             {
#                 "contour": 2.0,
#                 "index": 201
#             }
#         ],
#         "contour": 828.5,
#         "index": 199
#     },
#     "203": {
#         "childRegion": [],
#         "contour": 3272.5,
#         "index": 202
#     },
#     "205": {
#         "childRegion": [],
#         "contour": 5936.5,
#         "index": 204
#     },
#     "207": {
#         "childRegion": [],
#         "contour": 1832.5,
#         "index": 206
#     },
#     "209": {
#         "childRegion": [],
#         "contour": 6855.0,
#         "index": 208
#     },
#     "211": {
#         "childRegion": [
#             {
#                 "contour": 0.0,
#                 "index": 212
#             },
#             {
#                 "contour": 2652.0,
#                 "index": 213
#             },
#             {
#                 "contour": 1.0,
#                 "index": 215
#             }
#         ],
#         "contour": 4704.5,
#         "index": 210
#     },
#     "217": {
#         "childRegion": [],
#         "contour": 6.0,
#         "index": 216
#     },
#     "218": {
#         "childRegion": [],
#         "contour": 1619.5,
#         "index": 217
#     },
#     "219": {
#         "childRegion": [
#             {
#                 "contour": 834.5,
#                 "index": 220
#             }
#         ],
#         "contour": 1613.5,
#         "index": 218
#     },
#     "223": {
#         "childRegion": [],
#         "contour": 1404.0,
#         "index": 222
#     },
#     "224": {
#         "childRegion": [
#             {
#                 "contour": 669.0,
#                 "index": 225
#             }
#         ],
#         "contour": 1395.0,
#         "index": 223
#     },
#     "228": {
#         "childRegion": [],
#         "contour": 7398.0,
#         "index": 227
#     },
#     "230": {
#         "childRegion": [
#             {
#                 "contour": 5464.5,
#                 "index": 231
#             }
#         ],
#         "contour": 7124.5,
#         "index": 229
#     },
#     "234": {
#         "childRegion": [
#             {
#                 "contour": 5654.0,
#                 "index": 235
#             }
#         ],
#         "contour": 7368.0,
#         "index": 233
#     },
#     "238": {
#         "childRegion": [
#             {
#                 "contour": 257.0,
#                 "index": 239
#             },
#             {
#                 "contour": 6587.5,
#                 "index": 241
#             }
#         ],
#         "contour": 9084.0,
#         "index": 237
#     },
#     "244": {
#         "childRegion": [],
#         "contour": 542.0,
#         "index": 243
#     },
#     "246": {
#         "childRegion": [],
#         "contour": 6160.5,
#         "index": 245
#     },
#     "247": {
#         "childRegion": [
#             {
#                 "contour": 4688.0,
#                 "index": 248
#             }
#         ],
#         "contour": 6151.5,
#         "index": 246
#     }
# }
